# %% [markdown]
# La première version de ce notebook a été corrompue pour des raisons inconnues, donc on cherche à en faire une version plus simple cette fois.
#
# Comme précédemment, il est conseillé que vous réalisiez ces analyses par vos soins, car le dataset évolue avec le temps.

# %%
import pandas as pd

data =  pd.read_csv('../data/eco2mix_2025.csv', sep=";")
data.head()
# Out:
#    code_insee_region      libelle_region              nature        date  \
# 0                 75  Nouvelle-Aquitaine  Données temps réel  2025-05-23
# 1                 75  Nouvelle-Aquitaine  Données temps réel  2025-05-23
# 2                 75  Nouvelle-Aquitaine  Données temps réel  2025-05-23
# 3                 75  Nouvelle-Aquitaine  Données temps réel  2025-05-23
# 4                 75  Nouvelle-Aquitaine  Données temps réel  2025-05-23
#
#    heure                 date_heure  consommation  thermique  nucleaire  \
# 0  09:30  2025-05-23T07:30:00+00:00          3771         30       2549
# 1  11:45  2025-05-23T09:45:00+00:00          3600         30       2558
# 2  13:30  2025-05-23T11:30:00+00:00          3636         30       1959
# 3  15:00  2025-05-23T13:00:00+00:00          3448         30       1927
# 4  17:00  2025-05-23T15:00:00+00:00          2702         30       1192
#
#    eolien  ...  tch_nucleaire  tco_eolien  tch_eolien  tco_solaire  \
# ...

# %%
data.columns
# Out:
# Index(['code_insee_region', 'libelle_region', 'nature', 'date', 'heure',
#        'date_heure', 'consommation', 'thermique', 'nucleaire', 'eolien',
#        'solaire', 'hydraulique', 'pompage', 'bioenergies', 'ech_physiques',
#        'stockage_batterie', 'destockage_batterie', 'tco_thermique',
#        'tch_thermique', 'tco_nucleaire', 'tch_nucleaire', 'tco_eolien',
#        'tch_eolien', 'tco_solaire', 'tch_solaire', 'tco_hydraulique',
#        'tch_hydraulique', 'tco_bioenergies', 'tch_bioenergies', 'column_68'],
#       dtype='object')

# %% [markdown]
# Initialement, j'avais réalisé des tests pour déterminer les colonnes avec des NaN et pour déterminer l'existence de certaines irrégularités (valeurs négatives), mais sachant que l'on réalise l'audit de qualité avec Python + Great Expectations, j'ai décidé de ne pas répéter l'analyse ici.
